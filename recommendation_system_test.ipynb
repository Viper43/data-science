# %%
import pandas as pa
import io
from google.colab import files

filename = input()
uploaded = files.upload()
df = pa.read_csv(io.BytesIO(uploaded[filename]), encoding='latin1')
df.head()
# Out:
# data.csv
#      <input type="file" id="files-4cac34ca-7ea5-4933-85f1-452e62ab80ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4cac34ca-7ea5-4933-85f1-452e62ab80ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data.csv
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
#df = df[(df['InvoiceNo'] != -1)]
new_df = df.dropna(axis = 'index', subset = ['InvoiceNo'])
new_df.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
new_df['Description'] = new_df['Description'].str.strip()
  
# Dropping the rows without any invoice number
new_df.dropna(axis = 0, subset =['InvoiceNo'], inplace = True)
new_df['InvoiceNo'] = new_df['InvoiceNo'].astype('str')

# Dropping all transactions which were done on credit
new_df = new_df[~new_df['InvoiceNo'].str.contains('C')]

# %%
# basket = (new_df.groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))
basket = (new_df[new_df['Country'] =="France"].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))
basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                          0.0  ...                              0.0
# 536852                          0.0  ...                              0.0
# 536974                          0.0  ...                              0.0
# 537065                          0.0  ...                              0.0
# 537463                          0.0  ...                              0.0
# ...                             ...  ...                              ...
# 580986                          0.0  ...                              0.0
# 581001                          0.0  ...                              0.0
# 581171                          0.0  ...                              0.0
# 581279                          0.0  ...                              0.0
# 581587                          0.0  ...                              0.0
#
# [392 rows x 1563 columns]

# %%
def hot_encode(x):
    if(x<= 0):
        return 0
    if(x>= 1):
        return 1

# %%
basket_encoded = basket.applymap(hot_encode)
basket_encoded.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                            0  ...                                0
# 536852                            0  ...                                0
# 536974                            0  ...                                0
# 537065                            0  ...                                0
# 537463                            0  ...                                0
#
# [5 rows x 1563 columns]

# %%
from mlxtend.frequent_patterns import apriori, association_rules

frq_items = apriori(basket_encoded, min_support = 0.05, use_colnames = True)
frq_items['length'] = frq_items['itemsets'].apply(lambda x: len(x))
frq_items
# Out:
#       support                                           itemsets  length
# 0    0.071429                      (4 TRADITIONAL SPINNING TOPS)       1
# 1    0.096939                       (ALARM CLOCK BAKELIKE GREEN)       1
# 2    0.102041                        (ALARM CLOCK BAKELIKE PINK)       1
# 3    0.094388                         (ALARM CLOCK BAKELIKE RED)       1
# 4    0.068878                       (ASSORTED COLOUR MINI CASES)       1
# ..        ...                                                ...     ...
# 190  0.102041  (POSTAGE, SET/6 RED SPOTTY PAPER CUPS, SET/6 R...       3
# 191  0.099490  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...       3
# 192  0.056122  (POSTAGE, ALARM CLOCK BAKELIKE GREEN, ALARM CL...       4
# 193  0.053571  (PLASTERS IN TIN SPACEBOY, POSTAGE, PLASTERS I...       4
# 194  0.081633  (POSTAGE, SET/20 RED RETROSPOT PAPER NAPKINS, ...       4
#
# [195 rows x 3 columns]

# %%
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head(20)
# Out:
#                                            antecedents  ... conviction
# 45                        (JUMBO BAG WOODLAND ANIMALS)  ...        inf
# 260  (PLASTERS IN TIN CIRCUS PARADE, RED TOADSTOOL ...  ...        inf
# 271  (PLASTERS IN TIN WOODLAND ANIMALS, RED TOADSTO...  ...        inf
# 300  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...  ...  34.897959
# 301  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...  ...  34.489796
# 334  (POSTAGE, SET/20 RED RETROSPOT PAPER NAPKINS, ...  ...  28.790816
# 335  (POSTAGE, SET/20 RED RETROSPOT PAPER NAPKINS, ...  ...  28.454082
# 129                         (RED RETROSPOT PICNIC BAG)  ...   6.571429
# 142                    (SET OF 9 BLACK SKULL BALLOONS)  ...   6.102041
# 175                    (SET/6 RED SPOTTY PAPER PLATES)  ...  21.556122
# 89                        (PACK OF 6 SKULL PAPER CUPS)  ...   5.867347
# 135                (RETROSPOT PARTY BAG + STICKER SET)  ...   5.632653
# ...
